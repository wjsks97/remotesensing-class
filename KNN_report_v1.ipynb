# %% [markdown]
# <a href="https://colab.research.google.com/github/wjsks97/remotesensing-class/blob/main/KNN_report_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import os.path
import matplotlib.pyplot as plt
import rasterio
from rasterio.plot import show
fname_img = "L1C_T52SDD_A029301_20221016T021304.tif"
! gdown --id 1y1P3N5Sd4XrEIE_UC23pbwZfUBXUEFHZ
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1y1P3N5Sd4XrEIE_UC23pbwZfUBXUEFHZ
# To: /content/L1C_T52SDD_A029301_20221016T021304.tif
# 100% 18.8M/18.8M [00:00<00:00, 203MB/s]

# %%
os.path.isfile(fname_img)
# Out:
# True

# %%
img = rasterio.open(fname_img)

# %%
show(img)

# %%
type(img)
I = img.read()
I.shape
# Out:
# (9, 702, 744)

# %%
type(I)
# Out:
# numpy.ndarray

# %%
I = np.swapaxes(I, 0, 2)

# %%
I.shape
# Out:
# (744, 702, 9)

# %%
I[0,1,:]
# Out:
# array([0.0307, 0.0473, 0.0341, 0.0773, 0.2841, 0.3611, 0.4039, 0.2124,
#        0.0954], dtype=float32)
